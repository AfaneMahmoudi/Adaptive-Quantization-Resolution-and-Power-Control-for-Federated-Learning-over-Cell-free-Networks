# %%
import numpy as np

# Define parameters (example values, replace with actual parameters)
T = 3  # number of time slots
K = 4  # number of users
A_bar = np.array([1.0, 0.9, 1.1, 1.2])  # Example values for A_bar
B_bar = np.array([0.1, 0.1, 0.2, 0.1])  # Example values for B_bar
B_tilde = np.array([[0.0, 0.05, 0.02, 0.01],
                    [0.05, 0.0, 0.03, 0.02],
                    [0.02, 0.03, 0.0, 0.04],
                    [0.01, 0.02, 0.04, 0.0]])  # Example values for B_tilde
I_M = np.array([0.1, 0.2, 0.1, 0.15])  # Example values for I_M
b_t = np.random.rand(T, K)  # Random values for b_t (replace with actual values)

# Function to check feasibility of power allocations
def check_feasibility(eta_t, A_bar, B_bar, B_tilde, I_M, b_t, T, K):
    for t in range(T):
        p_t = np.zeros(K)
        gamma_t = np.zeros(K)
        for j in range(K):
            gamma_t[j] = 2 ** (eta_t * b_t[t, j]) - 1
        for j in range(K):
            numerator = gamma_t[j] * (np.sum(p_t * B_tilde[j]) + I_M[j])
            denominator = A_bar[j] - gamma_t[j] * B_bar[j]
            if denominator <= 0:
                return False
            p_t[j] = numerator / denominator
            if p_t[j] < 0 or p_t[j] > 1:
                return False
    return True

# Iteratively find maximum eta_t
def maximize_eta_t(A_bar, B_bar, B_tilde, I_M, b_t, T, K, eta_t_start=0.1, eta_t_step=0.01, max_iterations=1000):
    eta_t = eta_t_start
    for _ in range(max_iterations):
        if check_feasibility(eta_t, A_bar, B_bar, B_tilde, I_M, b_t, T, K):
            eta_t += eta_t_step
        else:
            eta_t -= eta_t_step
            break
    return eta_t

# Example usage
max_eta_t = maximize_eta_t(A_bar, B_bar, B_tilde, I_M, b_t, T, K)
print("Maximum eta_t:", max_eta_t)
# Out:
# C:\Users\afmb\Anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\afmb\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.EL2C6PLE4ZYW3ECEVIV3OXXGRN2NRFM2.gfortran-win_amd64.dll
# C:\Users\afmb\Anaconda3\lib\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"
# Maximum eta_t: 2.1299999999999986

# %%
import numpy as np

# Define parameters (example values, replace with actual parameters)
T = 3  # number of time slots
K = 4  # number of users
A_bar = np.array([1.0, 0.9, 1.1, 1.2])  # Example values for A_bar
B_bar = np.array([0.1, 0.1, 0.2, 0.1])  # Example values for B_bar
B_tilde = np.array([[0.0, 0.05, 0.02, 0.01],
                    [0.05, 0.0, 0.03, 0.02],
                    [0.02, 0.03, 0.0, 0.04],
                    [0.01, 0.02, 0.04, 0.0]])  # Example values for B_tilde
I_M = np.array([0.1, 0.2, 0.1, 0.15])  # Example values for I_M
b_t = np.random.rand(T, K)  # Random values for b_t (replace with actual values)

# Function to check feasibility of power allocations and return power values
def check_feasibility(eta_t, A_bar, B_bar, B_tilde, I_M, b_t, T, K):
    powers = []
    for t in range(T):
        p_t = np.zeros(K)
        gamma_t = np.zeros(K)
        for j in range(K):
            gamma_t[j] = 2 ** (eta_t * b_t[t, j]) - 1
        for j in range(K):
            numerator = gamma_t[j] * (np.sum(p_t * B_tilde[j]) + I_M[j])
            denominator = A_bar[j] - gamma_t[j] * B_bar[j]
            if denominator <= 0:
                return False, None
            p_t[j] = numerator / denominator
            if p_t[j] < 0 or p_t[j] > 1:
                return False, None
        powers.append(p_t)
    return True, powers

# Iteratively find maximum eta_t and store power allocations
def maximize_eta_t(A_bar, B_bar, B_tilde, I_M, b_t, T, K, eta_t_start=0.001, eta_t_step=0.1, max_iterations=1000):
    eta_t = eta_t_start
    best_eta_t = eta_t
    best_powers = None
    for _ in range(max_iterations):
        feasible, powers = check_feasibility(eta_t, A_bar, B_bar, B_tilde, I_M, b_t, T, K)
        if feasible:
            best_eta_t = eta_t
            best_powers = powers
            eta_t += eta_t_step
        else:
            break
    return best_eta_t, best_powers

# Example usage
max_eta_t, optimal_powers = maximize_eta_t(A_bar, B_bar, B_tilde, I_M, b_t, T, K)
print("Maximum eta_t:", max_eta_t)
print("Optimal power allocations:")
for t in range(T):
    print(f"Time slot {t + 1}: {optimal_powers[t]}")
# Out:
# Maximum eta_t: 2.201000000000001
# Optimal power allocations:
# Time slot 1: [0.27467488 0.032932   0.73955971 0.46446772]
# Time slot 2: [0.42282353 0.22812505 0.92497117 0.33298435]
# Time slot 3: [0.01236299 0.00965923 0.08691739 0.27843299]

# %%
import numpy as np
from scipy.optimize import linprog

# Define parameters (example values, replace with actual parameters)
T = 3  # number of time slots
K = 4  # number of users
A_bar = np.array([1.0, 0.9, 1.1, 1.2])  # Example values for A_bar
B_bar = np.array([0.1, 0.1, 0.2, 0.1])  # Example values for B_bar
B_tilde = np.array([[0.0, 0.05, 0.02, 0.01],
                    [0.05, 0.0, 0.03, 0.02],
                    [0.02, 0.03, 0.0, 0.04],
                    [0.01, 0.02, 0.04, 0.0]])  # Example values for B_tilde
I_M = np.array([0.1, 0.2, 0.1, 0.15])  # Example values for I_M
b_t = np.random.rand(T, K)  # Random values for b_t (replace with actual values)

# Function to construct the linear programming problem
def construct_lp_problem(eta_t, A_bar, B_bar, B_tilde, I_M, b_t, T, K):
    c = np.zeros(T * K)  # Objective function coefficients (zeros since we're not optimizing p directly)
    bounds = [(0, 1)] * (T * K)  # Bounds for each p_t^j
    
    # Constraints
    A = []
    b = []
    
    for t in range(T):
        for j in range(K):
            gamma_t_j = 2 ** (eta_t * b_t[t, j]) - 1
            row = np.zeros(T * K)
            row[t * K + j] = A_bar[j] - gamma_t_j * B_bar[j]
            for j_prime in range(K):
                if j_prime != j:
                    row[t * K + j_prime] = -gamma_t_j * B_tilde[j, j_prime]
            A.append(row)
            b.append(gamma_t_j * I_M[j])
    
    return np.array(A), np.array(b), c, bounds

# Function to maximize eta_t using linear programming
def maximize_eta_t_lp(A_bar, B_bar, B_tilde, I_M, b_t, T, K, eta_t_start=0.1, eta_t_step=0.01, max_iterations=1000):
    eta_t = eta_t_start
    best_eta_t = eta_t
    best_powers = None
    for _ in range(max_iterations):
        A, b, c, bounds = construct_lp_problem(eta_t, A_bar, B_bar, B_tilde, I_M, b_t, T, K)
        res = linprog(c, A_ub=A, b_ub=b, bounds=bounds, method='highs')
        if res.success:
            best_eta_t = eta_t
            best_powers = res.x
            eta_t += eta_t_step
        else:
            break
    return best_eta_t, best_powers

# Example usage
max_eta_t_lp, optimal_powers_lp = maximize_eta_t_lp(A_bar, B_bar, B_tilde, I_M, b_t, T, K)
print("Maximum eta_t (LP):", max_eta_t_lp)
print("Optimal power allocations (LP):")
for t in range(T):
    print(f"Time slot {t + 1}: {optimal_powers_lp[t * K:(t + 1) * K]}")

# Comparison with analytical method
def maximize_eta_t_analytical(A_bar, B_bar, B_tilde, I_M, b_t, T, K, eta_t_start=0.1, eta_t_step=0.01, max_iterations=1000):
    eta_t = eta_t_start
    best_eta_t = eta_t
    best_powers = None
    for _ in range(max_iterations):
        feasible, powers = check_feasibility(eta_t, A_bar, B_bar, B_tilde, I_M, b_t, T, K)
        if feasible:
            best_eta_t = eta_t
            best_powers = powers
            eta_t += eta_t_step
        else:
            break
    return best_eta_t, best_powers

max_eta_t_analytical, optimal_powers_analytical = maximize_eta_t_analytical(A_bar, B_bar, B_tilde, I_M, b_t, T, K)
print("Maximum eta_t (Analytical):", max_eta_t_analytical)
print("Optimal power allocations (Analytical):")
for t in range(T):
    print(f"Time slot {t + 1}: {optimal_powers_analytical[t]}")
# Out:
# Maximum eta_t (LP): 10.08999999999983
# Optimal power allocations (LP):
# Time slot 1: [1. 1. 0. 0.]
# Time slot 2: [0. 0. 0. 0.]
# Time slot 3: [0. 0. 0. 0.]
# Maximum eta_t (Analytical): 2.6899999999999866
# Optimal power allocations (Analytical):
# Time slot 1: [0.23356001 0.19112289 0.01657727 0.06473388]
# Time slot 2: [0.13565495 0.03178939 0.66838252 0.40092387]
# Time slot 3: [0.07882212 0.99646468 0.00728141 0.25841178]

# %%
import numpy as np

# Define parameters
T = 1  # single time slot for simplicity
K = 5  # number of users
B_tilde = np.array([[0.0, 0.00280774, 0.00227045, 0.00599378, 0.00054239],
                    [0.00280774, 0.0, 0.00090963, 0.10872945, 0.00079498],
                    [0.00227045, 0.00090963, 0.0, 0.00180449, 0.03946987],
                    [0.00599378, 0.10872945, 0.00180449, 0.0, 0.00094696],
                    [0.00054239, 0.00079498, 0.03946987, 0.00094696, 0.0]])
A_bar = 2 * np.array([0.038254, 0.37979634, 6.42646204, 1.4801049, 1.43769989])
B_bar = np.array([0.00206423, 0.04449928, 1.3862424, 0.29103015, 0.29611187])
I_M = np.array([7.78643045e-13, 2.45343970e-12, 1.00922029e-11, 4.84335440e-12, 4.77346915e-12])
beta = np.array([8, 6, 8, 2, 7])

# Function to check feasibility of power allocations and return power values
def check_feasibility(eta_t, A_bar, B_bar, B_tilde, I_M, beta, T, K):
    powers = []
    for t in range(T):
        p_t = np.zeros(K)
        gamma_t = np.zeros(K)
        for j in range(K):
            gamma_t[j] = 2 ** (eta_t * beta[j]) - 1
        for j in range(K):
            numerator = gamma_t[j] * (np.sum(p_t * B_tilde[j]) + I_M[j])
            denominator = A_bar[j] - gamma_t[j] * B_bar[j]
            if denominator <= 0:
                return False, None
            p_t[j] = numerator / denominator
            if p_t[j] < 0 or p_t[j] > 1:
                return False, None
        powers.append(p_t)
    return True, powers

# Bisection method to find maximum eta_t and store power allocations
def bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, beta, T, K, eta_t_lower=0.0, eta_t_upper=10.0, tolerance=1e-6):
    best_eta_t = eta_t_lower
    best_powers = None
    while eta_t_upper - eta_t_lower > tolerance:
        eta_t_mid = (eta_t_lower + eta_t_upper) / 2.0
        feasible, powers = check_feasibility(eta_t_mid, A_bar, B_bar, B_tilde, I_M, beta, T, K)
        if feasible:
            best_eta_t = eta_t_mid
            best_powers = powers
            eta_t_lower = eta_t_mid
        else:
            eta_t_upper = eta_t_mid
    return best_eta_t, best_powers

# Example usage
max_eta_t, optimal_powers = bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, beta, T, K)
print("Maximum eta_t:", max_eta_t)
print("Optimal power allocations:")
for t in range(T):
    print(f"Time slot {t + 1}: {optimal_powers[t]}")
# Out:
# Maximum eta_t: 0.42007625102996826
# Optimal power allocations:
# Time slot 1: [1.25841241e-10 2.42313463e-11 3.02162453e-06 1.58055715e-09
#  8.86540154e-07]

# %%
import numpy as np

# Define parameters
K = 5  # number of users
T = 1  # number of time slots, we assume one slot for simplicity
B_tilde = np.array([[0.0, 0.00280774, 0.00227045, 0.00599378, 0.00054239],
                    [0.00280774, 0.0, 0.00090963, 0.10872945, 0.00079498],
                    [0.00227045, 0.00090963, 0.0, 0.00180449, 0.03946987],
                    [0.00599378, 0.10872945, 0.00180449, 0.0, 0.00094696],
                    [0.00054239, 0.00079498, 0.03946987, 0.00094696, 0.0]])
A_bar = 2 * np.array([0.038254, 0.37979634, 6.42646204, 1.4801049, 1.43769989])
B_bar = np.array([0.00206423, 0.04449928, 1.3862424, 0.29103015, 0.29611187])
I_M = np.array([7.78643045e-13, 2.45343970e-12, 1.00922029e-11, 4.84335440e-12, 4.77346915e-12])
beta = np.array([8, 6, 8, 2, 7])  # values for beta

# Function to check feasibility of power allocations and return power values
def check_feasibility(eta_t, A_bar, B_bar, B_tilde, I_M, beta, K):
    powers = 0.2*np.ones(K)
    gamma_t = 2 ** (eta_t * beta) - 1
    for j in range(K):
        numerator = gamma_t[j] * (np.sum(powers * B_tilde[j]) + I_M[j])
        denominator = A_bar[j] - gamma_t[j] * B_bar[j]
        if denominator <= 0:
            return False, None
        powers[j] = numerator / denominator
        if powers[j] < 0 or powers[j] > 1:
            return False, None
    return True, powers

# Bisection method to find maximum eta_t and store power allocations
def bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, beta, K, eta_t_lower=0.0, eta_t_upper=10.0, tolerance=1e-6):
    best_eta_t = eta_t_lower
    best_powers = None
    while eta_t_upper - eta_t_lower > tolerance:
        eta_t_mid = (eta_t_lower + eta_t_upper) / 2.0
        feasible, powers = check_feasibility(eta_t_mid, A_bar, B_bar, B_tilde, I_M, beta, K)
        if feasible:
            best_eta_t = eta_t_mid
            best_powers = powers
            eta_t_lower = eta_t_mid
        else:
            eta_t_upper = eta_t_mid
    return best_eta_t, best_powers

# Example usage
max_eta_t, optimal_powers = bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, beta, K)
print("Maximum eta_t:", max_eta_t)
print("Optimal power allocations:", optimal_powers)
# Out:
# Maximum eta_t: 0.4189908504486084
# Optimal power allocations: [0.37209255 0.19819429 0.99992324 0.00743238 0.29043525]

# %% [markdown]
# # The following works well. It is linear programming and bisection

# %% [markdown]
# #This is with while over linear programming:

# %%
import numpy as np
import math
import numpy.linalg as nl
# Define parameters
T = 1  # single time slot for simplicity
K = 5  # number of users
B_tilde = np.array([[0.0, 0.00280774, 0.00227045, 0.00599378, 0.00054239],
                    [0.00280774, 0.0, 0.00090963, 0.10872945, 0.00079498],
                    [0.00227045, 0.00090963, 0.0, 0.00180449, 0.03946987],
                    [0.00599378, 0.10872945, 0.00180449, 0.0, 0.00094696],
                    [0.00054239, 0.00079498, 0.03946987, 0.00094696, 0.0]])
A_bar = 1 * np.array([0.038254, 0.37979634, 6.42646204, 1.4801049, 1.43769989])
B_bar = np.array([0.00206423, 0.04449928, 1.3862424, 0.29103015, 0.29611187])
I_M = np.array([7.78643045e-13, 2.45343970e-12, 1.00922029e-11, 4.84335440e-12, 4.77346915e-12])
beta = np.array([8, 6, 8, 2, 7]) #the bits
eps = 0.6
# Function to check feasibility of power allocations and return power values
def check_feasibility(eta_t, A_bar, B_bar, B_tilde, I_M, beta, T, K):
    itr = 0
    powers = (1/K)*np.ones((T, K))
    powers_old = 10*(1/K)*np.ones((T, K))
    for t in range(T):
        gamma_t = 2 ** (eta_t * beta) - 1
        # Solve the system of linear equations for power allocations
        while(np.linalg.norm(powers-powers_old, ord=np.inf) > eps):
            itr += 1
            print('iteration of LP:', itr)
            powers_old = np.copy(powers)
            for j in range(K):
                numerator = gamma_t[j] * (np.sum(powers[t] * B_tilde[j]) + I_M[j])
                denominator = A_bar[j] - gamma_t[j] * B_bar[j]
                if denominator <= 0:
                    return False, None
                powers[t, j] = numerator / denominator
        # Check feasibility of the computed powers
        if np.any(powers[t] < 0) or np.any(powers[t] > 1):
            return False, None
        #print('iteration of LP:', itr)
    return True, powers

# Function to compute SINR_t^j given powers
def compute_SINR(eta_t, powers, A_bar, B_bar, B_tilde, I_M, beta):
    T, K = powers.shape
    SINR = np.zeros((T, K))
    for t in range(T):
        gamma_t = 2 ** (eta_t * beta) - 1
        for j in range(K):
            interference = np.sum(powers[t] * B_tilde[j]) + I_M[j]
            SINR[t, j] = A_bar[j] * powers[t, j] / (B_bar[j] * powers[t, j] + interference)
    return SINR

# Function to compute latencies ell_t^j given SINR_t^j
def compute_latencies(SINR, beta):
    T, K = SINR.shape
    latencies = np.zeros((T, K))
    for t in range(T):
        for j in range(K):
            if SINR[t, j] > 0:
                latencies[t, j] = beta[j] / math.log2(1 + SINR[t, j])
            else:
                latencies[t, j] = float('inf')  # Handle cases where SINR[t, j] is zero
    return latencies

# Bisection method to find maximum eta_t and store power allocations
def bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, beta, T, K, eta_t_lower=0.0, eta_t_upper=10.0, tolerance=1e-6):
    itr_Bis = 0
    best_eta_t = eta_t_lower
    best_powers = None
    while eta_t_upper - eta_t_lower > tolerance:
        itr_Bis += 1
        
        eta_t_mid = (eta_t_lower + eta_t_upper) / 2.0
        feasible, powers = check_feasibility(eta_t_mid, A_bar, B_bar, B_tilde, I_M, beta, T, K)
        if feasible:
            best_eta_t = eta_t_mid
            best_powers = powers
            eta_t_lower = eta_t_mid
        else:
            eta_t_upper = eta_t_mid
    print('Bisection iteration:', itr_Bis)
    return best_eta_t, best_powers

# Example usage
max_eta_t, optimal_powers = bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, beta, T, K)
print("Maximum eta_t:", max_eta_t)
print("Optimal power allocations:")
for t in range(T):
    print(f"Time slot {t + 1}: {optimal_powers[t]}")

# Compute SINR and latencies
SINR_optimal = compute_SINR(max_eta_t, optimal_powers, A_bar, B_bar, B_tilde, I_M, beta)
latencies_optimal = compute_latencies(SINR_optimal, beta)

# Print latencies
print("\nLatencies:")
#for t in range(T):
for j in range(K):
    print(f" User {j + 1}: {latencies_optimal[t, j]}")
# Out:
# iteration of LP: 1
# iteration of LP: 1
# iteration of LP: 1
# iteration of LP: 1
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 1
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 1
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 3
# iteration of LP: 4
# iteration of LP: 5
# iteration of LP: 6
# iteration of LP: 7
# iteration of LP: 8
# iteration of LP: 9
# iteration of LP: 10
# iteration of LP: 11
# iteration of LP: 12
# iteration of LP: 13
# iteration of LP: 14
# iteration of LP: 15
# iteration of LP: 16
# iteration of LP: 17
# iteration of LP: 18
# iteration of LP: 19
# iteration of LP: 20
# iteration of LP: 21
# iteration of LP: 22
# iteration of LP: 23
# iteration of LP: 24
# iteration of LP: 25
# iteration of LP: 26
# iteration of LP: 27
# iteration of LP: 28
# iteration of LP: 29
# iteration of LP: 30
# iteration of LP: 31
# iteration of LP: 32
# iteration of LP: 33
# iteration of LP: 34
# iteration of LP: 35
# iteration of LP: 36
# iteration of LP: 37
# iteration of LP: 38
# iteration of LP: 39
# iteration of LP: 40
# iteration of LP: 41
# iteration of LP: 42
# iteration of LP: 43
# iteration of LP: 44
# iteration of LP: 45
# iteration of LP: 46
# iteration of LP: 47
# iteration of LP: 48
# iteration of LP: 49
# iteration of LP: 50
# iteration of LP: 51
# iteration of LP: 52
# iteration of LP: 53
# iteration of LP: 54
# iteration of LP: 55
# iteration of LP: 56
# iteration of LP: 57
# iteration of LP: 58
# iteration of LP: 59
# iteration of LP: 60
# iteration of LP: 61
# iteration of LP: 62
# iteration of LP: 63
# iteration of LP: 64
# iteration of LP: 65
# iteration of LP: 66
# iteration of LP: 67
# iteration of LP: 68
# iteration of LP: 69
# iteration of LP: 70
# iteration of LP: 71
# iteration of LP: 72
# iteration of LP: 73
# iteration of LP: 74
# iteration of LP: 213
# iteration of LP: 214
# iteration of LP: 215
# iteration of LP: 216
# iteration of LP: 217
# iteration of LP: 218
# iteration of LP: 219
# iteration of LP: 220
# iteration of LP: 221
# iteration of LP: 222
# iteration of LP: 223
# iteration of LP: 224
# iteration of LP: 225
# iteration of LP: 226
# iteration of LP: 227
# iteration of LP: 228
# iteration of LP: 229
# iteration of LP: 230
# iteration of LP: 231
# iteration of LP: 232
# iteration of LP: 233
# iteration of LP: 234
# iteration of LP: 235
# iteration of LP: 236
# iteration of LP: 237
# iteration of LP: 238
# iteration of LP: 239
# iteration of LP: 240
# iteration of LP: 241
# iteration of LP: 242
# iteration of LP: 243
# iteration of LP: 244
# iteration of LP: 245
# iteration of LP: 246
# iteration of LP: 247
# iteration of LP: 248
# iteration of LP: 249
# iteration of LP: 250
# iteration of LP: 251
# iteration of LP: 252
# iteration of LP: 253
# iteration of LP: 254
# iteration of LP: 255
# iteration of LP: 256
# iteration of LP: 257
# iteration of LP: 258
# iteration of LP: 259
# iteration of LP: 260
# iteration of LP: 261
# iteration of LP: 262
# iteration of LP: 263
# iteration of LP: 264
# iteration of LP: 265
# iteration of LP: 266
# iteration of LP: 267
# iteration of LP: 268
# iteration of LP: 269
# iteration of LP: 270
# iteration of LP: 271
# iteration of LP: 272
# iteration of LP: 273
# iteration of LP: 274
# iteration of LP: 275
# iteration of LP: 276
# iteration of LP: 277
# iteration of LP: 278
# iteration of LP: 279
# iteration of LP: 280
# iteration of LP: 281
# iteration of LP: 282
# iteration of LP: 283
# iteration of LP: 284
# iteration of LP: 285
# iteration of LP: 286
# iteration of LP: 287
# iteration of LP: 288
# iteration of LP: 289
# iteration of LP: 290
# iteration of LP: 291
# iteration of LP: 292
# iteration of LP: 293
# iteration of LP: 294
# iteration of LP: 295
# iteration of LP: 296
# iteration of LP: 297
# iteration of LP: 298
# iteration of LP: 299
# iteration of LP: 300
# iteration of LP: 301
# iteration of LP: 302
# iteration of LP: 303
# iteration of LP: 304
# iteration of LP: 305
# iteration of LP: 306
# iteration of LP: 307
# iteration of LP: 308
# iteration of LP: 309
# iteration of LP: 310
# iteration of LP: 311
# iteration of LP: 312
# iteration of LP: 313
# iteration of LP: 314
# iteration of LP: 315
# iteration of LP: 316
# iteration of LP: 317
# iteration of LP: 318
# iteration of LP: 1
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 3
# iteration of LP: 4
# iteration of LP: 5
# iteration of LP: 6
# iteration of LP: 7
# iteration of LP: 8
# iteration of LP: 9
# iteration of LP: 10
# iteration of LP: 11
# iteration of LP: 12
# iteration of LP: 13
# iteration of LP: 14
# iteration of LP: 15
# iteration of LP: 16
# iteration of LP: 17
# iteration of LP: 18
# iteration of LP: 19
# iteration of LP: 20
# iteration of LP: 21
# iteration of LP: 22
# iteration of LP: 23
# iteration of LP: 24
# iteration of LP: 25
# iteration of LP: 26
# iteration of LP: 27
# iteration of LP: 28
# iteration of LP: 29
# iteration of LP: 30
# iteration of LP: 31
# iteration of LP: 32
# iteration of LP: 33
# iteration of LP: 34
# iteration of LP: 35
# iteration of LP: 36
# iteration of LP: 37
# iteration of LP: 38
# iteration of LP: 39
# iteration of LP: 40
# iteration of LP: 41
# iteration of LP: 42
# iteration of LP: 43
# iteration of LP: 44
# iteration of LP: 45
# iteration of LP: 46
# iteration of LP: 47
# iteration of LP: 48
# iteration of LP: 49
# iteration of LP: 50
# iteration of LP: 51
# iteration of LP: 52
# iteration of LP: 53
# iteration of LP: 54
# iteration of LP: 55
# iteration of LP: 56
# iteration of LP: 57
# iteration of LP: 58
# iteration of LP: 59
# iteration of LP: 60
# iteration of LP: 61
# iteration of LP: 62
# iteration of LP: 63
# iteration of LP: 64
# iteration of LP: 65
# iteration of LP: 66
# iteration of LP: 67
# iteration of LP: 68
# iteration of LP: 69
# iteration of LP: 70
# iteration of LP: 71
# iteration of LP: 72
# iteration of LP: 73
# iteration of LP: 74
# iteration of LP: 75
# iteration of LP: 76
# iteration of LP: 77
# iteration of LP: 78
# iteration of LP: 79
# iteration of LP: 80
# iteration of LP: 81
# iteration of LP: 82
# iteration of LP: 83
# iteration of LP: 84
# iteration of LP: 85
# iteration of LP: 86
# iteration of LP: 87
# iteration of LP: 88
# iteration of LP: 89
# iteration of LP: 90
# iteration of LP: 91
# iteration of LP: 92
# iteration of LP: 93
# iteration of LP: 94
# iteration of LP: 95
# iteration of LP: 96
# iteration of LP: 97
# iteration of LP: 98
# C:\Users\afmb\AppData\Local\Temp\ipykernel_12868\2002214089.py:34: RuntimeWarning: overflow encountered in double_scalars
#   powers[t, j] = numerator / denominator
# C:\Users\afmb\AppData\Local\Temp\ipykernel_12868\2002214089.py:30: RuntimeWarning: invalid value encountered in multiply
#   numerator = gamma_t[j] * (np.sum(powers[t] * B_tilde[j]) + I_M[j])
# iteration of LP: 99
# iteration of LP: 100
# iteration of LP: 101
# iteration of LP: 102
# iteration of LP: 103
# iteration of LP: 104
# iteration of LP: 105
# iteration of LP: 106
# iteration of LP: 107
# iteration of LP: 108
# iteration of LP: 109
# iteration of LP: 110
# iteration of LP: 111
# iteration of LP: 112
# iteration of LP: 113
# iteration of LP: 114
# iteration of LP: 115
# iteration of LP: 116
# iteration of LP: 117
# iteration of LP: 118
# iteration of LP: 119
# iteration of LP: 120
# iteration of LP: 121
# iteration of LP: 122
# iteration of LP: 123
# iteration of LP: 124
# iteration of LP: 125
# iteration of LP: 126
# iteration of LP: 127
# iteration of LP: 128
# iteration of LP: 129
# iteration of LP: 130
# iteration of LP: 131
# iteration of LP: 132
# iteration of LP: 133
# iteration of LP: 134
# iteration of LP: 135
# iteration of LP: 136
# iteration of LP: 137
# iteration of LP: 138
# iteration of LP: 139
# iteration of LP: 140
# iteration of LP: 141
# iteration of LP: 142
# iteration of LP: 143
# iteration of LP: 144
# iteration of LP: 145
# iteration of LP: 146
# iteration of LP: 147
# iteration of LP: 148
# iteration of LP: 978
# iteration of LP: 979
# iteration of LP: 980
# iteration of LP: 981
# iteration of LP: 982
# iteration of LP: 983
# iteration of LP: 984
# iteration of LP: 985
# iteration of LP: 986
# iteration of LP: 987
# iteration of LP: 988
# iteration of LP: 989
# iteration of LP: 990
# iteration of LP: 991
# iteration of LP: 992
# iteration of LP: 993
# iteration of LP: 994
# iteration of LP: 995
# iteration of LP: 996
# iteration of LP: 997
# iteration of LP: 998
# iteration of LP: 999
# iteration of LP: 1000
# iteration of LP: 1001
# iteration of LP: 1002
# iteration of LP: 1003
# iteration of LP: 1004
# iteration of LP: 1005
# iteration of LP: 1006
# iteration of LP: 1007
# iteration of LP: 1008
# iteration of LP: 1009
# iteration of LP: 1010
# iteration of LP: 1011
# iteration of LP: 1012
# iteration of LP: 1013
# iteration of LP: 1014
# iteration of LP: 1015
# iteration of LP: 1016
# iteration of LP: 1017
# iteration of LP: 1018
# iteration of LP: 1019
# iteration of LP: 1020
# iteration of LP: 1021
# iteration of LP: 1022
# iteration of LP: 1023
# iteration of LP: 1024
# iteration of LP: 1025
# iteration of LP: 1026
# iteration of LP: 1027
# iteration of LP: 1028
# iteration of LP: 1029
# iteration of LP: 1030
# iteration of LP: 1031
# iteration of LP: 1032
# iteration of LP: 1033
# iteration of LP: 1034
# iteration of LP: 1035
# iteration of LP: 1036
# iteration of LP: 1037
# iteration of LP: 1038
# iteration of LP: 1039
# iteration of LP: 1040
# iteration of LP: 1041
# iteration of LP: 1042
# iteration of LP: 1043
# iteration of LP: 1044
# iteration of LP: 1045
# iteration of LP: 1046
# iteration of LP: 1047
# iteration of LP: 1048
# iteration of LP: 1049
# iteration of LP: 1050
# iteration of LP: 1051
# iteration of LP: 1052
# iteration of LP: 1053
# iteration of LP: 1054
# iteration of LP: 1055
# iteration of LP: 1056
# iteration of LP: 1057
# iteration of LP: 1058
# iteration of LP: 1059
# iteration of LP: 1060
# iteration of LP: 1061
# iteration of LP: 1062
# iteration of LP: 1063
# iteration of LP: 1064
# iteration of LP: 1065
# iteration of LP: 1066
# iteration of LP: 1067
# iteration of LP: 1068
# iteration of LP: 1069
# iteration of LP: 1070
# iteration of LP: 1071
# iteration of LP: 1072
# iteration of LP: 1073
# iteration of LP: 1074
# iteration of LP: 1075
# iteration of LP: 1076
# iteration of LP: 1077
# iteration of LP: 1078
# iteration of LP: 1079
# iteration of LP: 1080
# iteration of LP: 1081
# iteration of LP: 1082
# iteration of LP: 1083
# iteration of LP: 1084
# iteration of LP: 1085
# iteration of LP: 1086
# iteration of LP: 1087
# iteration of LP: 1088
# iteration of LP: 1089
# iteration of LP: 1090
# iteration of LP: 1091
# iteration of LP: 1092
# iteration of LP: 1093
# iteration of LP: 1094
# iteration of LP: 1095
# iteration of LP: 1096
# iteration of LP: 1097
# iteration of LP: 1098
# iteration of LP: 1099
# iteration of LP: 1100
# iteration of LP: 1101
# iteration of LP: 1102
# iteration of LP: 1103
# iteration of LP: 1104
# iteration of LP: 1105
# iteration of LP: 1106
# iteration of LP: 1107
# iteration of LP: 1108
# iteration of LP: 1109
# iteration of LP: 1110
# iteration of LP: 1111
# iteration of LP: 1112
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 3
# iteration of LP: 4
# iteration of LP: 5
# iteration of LP: 6
# iteration of LP: 7
# iteration of LP: 8
# iteration of LP: 9
# iteration of LP: 10
# iteration of LP: 11
# iteration of LP: 12
# iteration of LP: 13
# iteration of LP: 14
# iteration of LP: 15
# iteration of LP: 16
# iteration of LP: 17
# iteration of LP: 18
# iteration of LP: 19
# iteration of LP: 20
# iteration of LP: 21
# iteration of LP: 22
# iteration of LP: 23
# iteration of LP: 24
# iteration of LP: 25
# iteration of LP: 26
# iteration of LP: 27
# iteration of LP: 28
# iteration of LP: 29
# iteration of LP: 30
# iteration of LP: 31
# iteration of LP: 32
# iteration of LP: 33
# iteration of LP: 34
# iteration of LP: 35
# iteration of LP: 36
# iteration of LP: 37
# iteration of LP: 38
# iteration of LP: 39
# iteration of LP: 40
# iteration of LP: 41
# iteration of LP: 42
# iteration of LP: 43
# iteration of LP: 44
# iteration of LP: 45
# iteration of LP: 46
# iteration of LP: 47
# iteration of LP: 48
# iteration of LP: 49
# iteration of LP: 50
# iteration of LP: 51
# iteration of LP: 52
# iteration of LP: 53
# iteration of LP: 54
# iteration of LP: 55
# iteration of LP: 56
# iteration of LP: 57
# iteration of LP: 58
# iteration of LP: 59
# iteration of LP: 60
# iteration of LP: 61
# iteration of LP: 62
# iteration of LP: 63
# iteration of LP: 64
# iteration of LP: 65
# iteration of LP: 66
# iteration of LP: 67
# iteration of LP: 68
# iteration of LP: 69
# iteration of LP: 70
# iteration of LP: 71
# iteration of LP: 72
# iteration of LP: 73
# iteration of LP: 74
# iteration of LP: 75
# iteration of LP: 76
# iteration of LP: 77
# iteration of LP: 78
# iteration of LP: 79
# iteration of LP: 80
# iteration of LP: 81
# iteration of LP: 82
# iteration of LP: 83
# iteration of LP: 84
# iteration of LP: 85
# iteration of LP: 86
# iteration of LP: 87
# iteration of LP: 88
# iteration of LP: 89
# iteration of LP: 90
# iteration of LP: 91
# iteration of LP: 92
# iteration of LP: 93
# iteration of LP: 94
# iteration of LP: 95
# iteration of LP: 96
# iteration of LP: 97
# iteration of LP: 98
# iteration of LP: 99
# iteration of LP: 100
# iteration of LP: 101
# iteration of LP: 102
# iteration of LP: 103
# iteration of LP: 104
# iteration of LP: 105
# iteration of LP: 106
# iteration of LP: 107
# iteration of LP: 108
# iteration of LP: 109
# iteration of LP: 110
# iteration of LP: 111
# iteration of LP: 112
# iteration of LP: 113
# iteration of LP: 114
# iteration of LP: 115
# iteration of LP: 116
# iteration of LP: 117
# iteration of LP: 118
# iteration of LP: 119
# iteration of LP: 120
# iteration of LP: 121
# iteration of LP: 122
# iteration of LP: 123
# iteration of LP: 124
# iteration of LP: 125
# iteration of LP: 126
# iteration of LP: 127
# iteration of LP: 128
# iteration of LP: 129
# iteration of LP: 130
# iteration of LP: 131
# iteration of LP: 1796
# iteration of LP: 1797
# iteration of LP: 1798
# iteration of LP: 1799
# iteration of LP: 1800
# iteration of LP: 1801
# iteration of LP: 1802
# iteration of LP: 1803
# iteration of LP: 1804
# iteration of LP: 1805
# iteration of LP: 1806
# iteration of LP: 1807
# iteration of LP: 1808
# iteration of LP: 1809
# iteration of LP: 1810
# iteration of LP: 1811
# iteration of LP: 1812
# iteration of LP: 1813
# iteration of LP: 1814
# iteration of LP: 1815
# iteration of LP: 1816
# iteration of LP: 1817
# iteration of LP: 1818
# iteration of LP: 1819
# iteration of LP: 1820
# iteration of LP: 1821
# iteration of LP: 1822
# iteration of LP: 1823
# iteration of LP: 1824
# iteration of LP: 1825
# iteration of LP: 1826
# iteration of LP: 1827
# iteration of LP: 1828
# iteration of LP: 1829
# iteration of LP: 1830
# iteration of LP: 1831
# iteration of LP: 1832
# iteration of LP: 1833
# iteration of LP: 1834
# iteration of LP: 1835
# iteration of LP: 1836
# iteration of LP: 1837
# iteration of LP: 1838
# iteration of LP: 1839
# iteration of LP: 1840
# iteration of LP: 1841
# iteration of LP: 1842
# iteration of LP: 1843
# iteration of LP: 1844
# iteration of LP: 1845
# iteration of LP: 1846
# iteration of LP: 1847
# iteration of LP: 1848
# iteration of LP: 1849
# iteration of LP: 1850
# iteration of LP: 1851
# iteration of LP: 1852
# iteration of LP: 1853
# iteration of LP: 1854
# iteration of LP: 1855
# iteration of LP: 1856
# iteration of LP: 1857
# iteration of LP: 1858
# iteration of LP: 1859
# iteration of LP: 1860
# iteration of LP: 1861
# iteration of LP: 1862
# iteration of LP: 1863
# iteration of LP: 1864
# iteration of LP: 1865
# iteration of LP: 1866
# iteration of LP: 1867
# iteration of LP: 1868
# iteration of LP: 1869
# iteration of LP: 1870
# iteration of LP: 1871
# iteration of LP: 1872
# iteration of LP: 1873
# iteration of LP: 1874
# iteration of LP: 1875
# iteration of LP: 1876
# iteration of LP: 1877
# iteration of LP: 1878
# iteration of LP: 1879
# iteration of LP: 1880
# iteration of LP: 1881
# iteration of LP: 1882
# iteration of LP: 1883
# iteration of LP: 1884
# iteration of LP: 1885
# iteration of LP: 1886
# iteration of LP: 1887
# iteration of LP: 1888
# iteration of LP: 1889
# iteration of LP: 1890
# iteration of LP: 1891
# iteration of LP: 1892
# iteration of LP: 1893
# iteration of LP: 1894
# iteration of LP: 1895
# iteration of LP: 1896
# iteration of LP: 1897
# iteration of LP: 1898
# iteration of LP: 1899
# iteration of LP: 1900
# iteration of LP: 1901
# iteration of LP: 1902
# iteration of LP: 1903
# iteration of LP: 1904
# iteration of LP: 1905
# iteration of LP: 1906
# iteration of LP: 1907
# iteration of LP: 1908
# iteration of LP: 1909
# iteration of LP: 1910
# iteration of LP: 1911
# iteration of LP: 1912
# iteration of LP: 1913
# iteration of LP: 1914
# iteration of LP: 1915
# iteration of LP: 1916
# iteration of LP: 1917
# iteration of LP: 1918
# iteration of LP: 1919
# iteration of LP: 1920
# iteration of LP: 1921
# iteration of LP: 1922
# iteration of LP: 1923
# iteration of LP: 1924
# iteration of LP: 1925
# iteration of LP: 1926
# iteration of LP: 1927
# iteration of LP: 1928
# iteration of LP: 1929
# iteration of LP: 1930
# iteration of LP: 1931
# iteration of LP: 1932
# iteration of LP: 1933
# iteration of LP: 1934
# iteration of LP: 1935
# iteration of LP: 1936
# iteration of LP: 1937
# iteration of LP: 1938
# iteration of LP: 1939
# iteration of LP: 1940
# iteration of LP: 1941
# iteration of LP: 1942
# iteration of LP: 1943
# iteration of LP: 1944
# iteration of LP: 1945
# iteration of LP: 1946
# iteration of LP: 1947
# iteration of LP: 1948
# iteration of LP: 1949
# iteration of LP: 1950
# iteration of LP: 1951
# iteration of LP: 1952
# iteration of LP: 1953
# iteration of LP: 1954
# iteration of LP: 1955
# iteration of LP: 1956
# iteration of LP: 1957
# iteration of LP: 1958
# iteration of LP: 1959
# iteration of LP: 1960
# iteration of LP: 1961
# iteration of LP: 1962
# iteration of LP: 1963
# iteration of LP: 1964
# iteration of LP: 1965
# iteration of LP: 1966
# iteration of LP: 1967
# iteration of LP: 1968
# iteration of LP: 1969
# iteration of LP: 1970
# iteration of LP: 1971
# iteration of LP: 1972
# iteration of LP: 1973
# iteration of LP: 1974
# iteration of LP: 1975
# iteration of LP: 1976
# iteration of LP: 1977
# iteration of LP: 1978
# iteration of LP: 1979
# iteration of LP: 1980
# iteration of LP: 1981
# iteration of LP: 1982
# iteration of LP: 1983
# iteration of LP: 1984
# iteration of LP: 1985
# iteration of LP: 1986
# iteration of LP: 1987
# iteration of LP: 1988
# iteration of LP: 1989
# iteration of LP: 1990
# iteration of LP: 1991
# iteration of LP: 1992
# iteration of LP: 1993
# iteration of LP: 1994
# iteration of LP: 1995
# iteration of LP: 1996
# iteration of LP: 1997
# iteration of LP: 1998
# iteration of LP: 1999
# iteration of LP: 2000
# iteration of LP: 2001
# iteration of LP: 2002
# iteration of LP: 2003
# iteration of LP: 2004
# iteration of LP: 2005
# iteration of LP: 2006
# iteration of LP: 2007
# iteration of LP: 2008
# iteration of LP: 2009
# iteration of LP: 2010
# iteration of LP: 2011
# iteration of LP: 2012
# iteration of LP: 2013
# iteration of LP: 2014
# iteration of LP: 2015
# iteration of LP: 2016
# iteration of LP: 2017
# iteration of LP: 2018
# iteration of LP: 2019
# iteration of LP: 2020
# iteration of LP: 2021
# iteration of LP: 2022
# iteration of LP: 2023
# iteration of LP: 2024
# iteration of LP: 2025
# iteration of LP: 2026
# iteration of LP: 2027
# iteration of LP: 2028
# iteration of LP: 2029
# iteration of LP: 2030
# iteration of LP: 2031
# iteration of LP: 2032
# iteration of LP: 2033
# iteration of LP: 2034
# iteration of LP: 2035
# iteration of LP: 2036
# iteration of LP: 2037
# iteration of LP: 2038
# iteration of LP: 2039
# iteration of LP: 2040
# iteration of LP: 2041
# iteration of LP: 2042
# iteration of LP: 2043
# iteration of LP: 2044
# iteration of LP: 2045
# iteration of LP: 2046
# iteration of LP: 2047
# iteration of LP: 2048
# iteration of LP: 2049
# iteration of LP: 2176
# iteration of LP: 2177
# iteration of LP: 2178
# iteration of LP: 2179
# iteration of LP: 2180
# iteration of LP: 2181
# iteration of LP: 2182
# iteration of LP: 2183
# iteration of LP: 2184
# iteration of LP: 2185
# iteration of LP: 2186
# iteration of LP: 2187
# iteration of LP: 2188
# iteration of LP: 2189
# iteration of LP: 2190
# iteration of LP: 2191
# iteration of LP: 2192
# iteration of LP: 2193
# iteration of LP: 2194
# iteration of LP: 2195
# iteration of LP: 2196
# iteration of LP: 2197
# iteration of LP: 2198
# iteration of LP: 2199
# iteration of LP: 2200
# iteration of LP: 2201
# iteration of LP: 2202
# iteration of LP: 2203
# iteration of LP: 2204
# iteration of LP: 2205
# iteration of LP: 2206
# iteration of LP: 2207
# iteration of LP: 2208
# iteration of LP: 2209
# iteration of LP: 2210
# iteration of LP: 2211
# iteration of LP: 2212
# iteration of LP: 2213
# iteration of LP: 2214
# iteration of LP: 2215
# iteration of LP: 2216
# iteration of LP: 2217
# iteration of LP: 2218
# iteration of LP: 2219
# iteration of LP: 2220
# iteration of LP: 2221
# iteration of LP: 2222
# iteration of LP: 2223
# iteration of LP: 2224
# iteration of LP: 2225
# iteration of LP: 2226
# iteration of LP: 2227
# iteration of LP: 2228
# iteration of LP: 2229
# iteration of LP: 2230
# iteration of LP: 2231
# iteration of LP: 2232
# iteration of LP: 2233
# iteration of LP: 2234
# iteration of LP: 2235
# iteration of LP: 2236
# iteration of LP: 2237
# iteration of LP: 2238
# iteration of LP: 2239
# iteration of LP: 2240
# iteration of LP: 2241
# iteration of LP: 2242
# iteration of LP: 2243
# iteration of LP: 2244
# iteration of LP: 2245
# iteration of LP: 2246
# iteration of LP: 2247
# iteration of LP: 2248
# iteration of LP: 2249
# iteration of LP: 2250
# iteration of LP: 2251
# iteration of LP: 2252
# iteration of LP: 2253
# iteration of LP: 2254
# iteration of LP: 2255
# iteration of LP: 2256
# iteration of LP: 2257
# iteration of LP: 2258
# iteration of LP: 2259
# iteration of LP: 2260
# iteration of LP: 2261
# iteration of LP: 2262
# iteration of LP: 2263
# iteration of LP: 2264
# iteration of LP: 2265
# iteration of LP: 2266
# iteration of LP: 2267
# iteration of LP: 2268
# iteration of LP: 2269
# iteration of LP: 2270
# iteration of LP: 2271
# iteration of LP: 2272
# iteration of LP: 2273
# iteration of LP: 2274
# iteration of LP: 2275
# iteration of LP: 2276
# iteration of LP: 2277
# iteration of LP: 2278
# iteration of LP: 2279
# iteration of LP: 2280
# iteration of LP: 2281
# iteration of LP: 2282
# iteration of LP: 2283
# iteration of LP: 2284
# iteration of LP: 2285
# iteration of LP: 2286
# iteration of LP: 2287
# iteration of LP: 2288
# iteration of LP: 2289
# iteration of LP: 2290
# iteration of LP: 2291
# iteration of LP: 2292
# iteration of LP: 2293
# iteration of LP: 2294
# iteration of LP: 2295
# iteration of LP: 2296
# iteration of LP: 2297
# iteration of LP: 2298
# iteration of LP: 2299
# iteration of LP: 2300
# iteration of LP: 2301
# iteration of LP: 2302
# iteration of LP: 2303
# iteration of LP: 2304
# iteration of LP: 2305
# iteration of LP: 2306
# iteration of LP: 2307
# iteration of LP: 2308
# iteration of LP: 2309
# iteration of LP: 2310
# iteration of LP: 2311
# iteration of LP: 2312
# iteration of LP: 2313
# iteration of LP: 2314
# iteration of LP: 2315
# iteration of LP: 2316
# iteration of LP: 2317
# iteration of LP: 2318
# iteration of LP: 2319
# iteration of LP: 2320
# iteration of LP: 2321
# iteration of LP: 2322
# iteration of LP: 2323
# iteration of LP: 2324
# iteration of LP: 2325
# iteration of LP: 2326
# iteration of LP: 2327
# iteration of LP: 2328
# iteration of LP: 2329
# iteration of LP: 2330
# iteration of LP: 2331
# iteration of LP: 2332
# iteration of LP: 2333
# iteration of LP: 2334
# iteration of LP: 2335
# iteration of LP: 2336
# iteration of LP: 2337
# iteration of LP: 2338
# iteration of LP: 2339
# iteration of LP: 2340
# iteration of LP: 2341
# iteration of LP: 2342
# iteration of LP: 2343
# iteration of LP: 2344
# iteration of LP: 2345
# iteration of LP: 2346
# iteration of LP: 2347
# iteration of LP: 2348
# iteration of LP: 2349
# iteration of LP: 2350
# iteration of LP: 2351
# iteration of LP: 2352
# iteration of LP: 2353
# iteration of LP: 2354
# iteration of LP: 2355
# iteration of LP: 2356
# iteration of LP: 2357
# iteration of LP: 2358
# iteration of LP: 2359
# iteration of LP: 2360
# iteration of LP: 2361
# iteration of LP: 2362
# iteration of LP: 2363
# iteration of LP: 2364
# iteration of LP: 2365
# iteration of LP: 2366
# iteration of LP: 2367
# iteration of LP: 2368
# iteration of LP: 2369
# iteration of LP: 2370
# iteration of LP: 2371
# iteration of LP: 2372
# iteration of LP: 2373
# iteration of LP: 2374
# iteration of LP: 2375
# iteration of LP: 2376
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 1
# iteration of LP: 2
# iteration of LP: 1
# iteration of LP: 2
# Bisection iteration: 24
# Maximum eta_t: 0.4188108444213867
# Optimal power allocations:
# Time slot 1: [0.42874791 0.02549727 0.99940207 0.00212714 0.28855504]
#
# Latencies:
#  User 1: 2.3430028125186193
#  User 2: 2.2748036145482247
#  User 3: 2.3887555587442013
#  User 4: 2.3962934059434504
#  User 5: 2.3877127665630584

# %% [markdown]
# #The following is without iterations over LP:

# %%
import numpy as np
import math
import numpy.linalg as nl
# Define parameters
T = 1  # single time slot for simplicity
K = 5  # number of users
B_tilde = np.array([[0.0, 0.00280774, 0.00227045, 0.00599378, 0.00054239],
                    [0.00280774, 0.0, 0.00090963, 0.10872945, 0.00079498],
                    [0.00227045, 0.00090963, 0.0, 0.00180449, 0.03946987],
                    [0.00599378, 0.10872945, 0.00180449, 0.0, 0.00094696],
                    [0.00054239, 0.00079498, 0.03946987, 0.00094696, 0.0]])
A_bar = 1 * np.array([0.038254, 0.37979634, 6.42646204, 1.4801049, 1.43769989])
B_bar = np.array([0.00206423, 0.04449928, 1.3862424, 0.29103015, 0.29611187])
I_M = np.array([7.78643045e-13, 2.45343970e-12, 1.00922029e-11, 4.84335440e-12, 4.77346915e-12])
beta = np.array([462410*32,462410*32, 462410*32, 462410*32, 462410*32]) #bits 462410*np.ones(K)*32
eps = 0.01

# Function to check feasibility of power allocations and return power values
def check_feasibility(eta_t, A_bar, B_bar, B_tilde, I_M, beta, T, K):
    itr = 0
    powers = (1/K)*np.ones(K)
    powers_old = 10*(1/K)*np.ones(K)
    for t in range(1):
        gamma_t = 2 ** (eta_t * beta) - 1
        # Solve the system of linear equations for power allocations
        while(itr < 1):
            itr +=1
            powers_old = np.copy(powers)
            for j in range(K):
                numerator = gamma_t[j] * (np.sum(powers[t] * B_tilde[j]) + I_M[j])
                denominator = A_bar[j] - gamma_t[j] * B_bar[j]
                if denominator <= 0:
                    return False, None
                powers[j] = numerator / denominator
        # Check feasibility of the computed powers
        if np.any(powers < 0) or np.any(powers > 1):
            return False, None
    return True, powers

# Function to compute SINR_t^j given powers
def compute_SINR(eta_t, powers, A_bar, B_bar, B_tilde, I_M, beta, K):
    #K = powers.shape
    SINR = np.zeros(K)
    for t in range(1):
        gamma_t = 2 ** (eta_t * beta/(2e6)) - 1
        for j in range(K):
            interference = np.sum(powers * B_tilde[j]) + I_M[j]
            SINR[ j] = A_bar[j] * powers[ j] / (B_bar[j] * powers[ j] + interference)
    return SINR

# Function to compute latencies ell_t^j given SINR_t^j
def compute_latencies(SINR, beta, K):
    #K = SINR.shape
    latencies = np.zeros(K)
    for t in range(1):
        for j in range(K):
            if SINR[ j] > 0:
                latencies[ j] = beta[j] / math.log2(1 + SINR[ j])
            else:
                latencies[ j] = float('inf')  # Handle cases where SINR[t, j] is zero
    return latencies

# Bisection method to find maximum eta_t and store power allocations
def bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, beta, T, K, eta_t_lower=0, eta_t_upper=10.0, tolerance=1e-6):
    itr_Bis = 0
    best_eta_t = eta_t_lower
    best_powers = None
    while eta_t_upper - eta_t_lower > tolerance:
        itr_Bis += 1
        
        eta_t_mid = (eta_t_lower + eta_t_upper) / 2.0
        feasible, powers = check_feasibility(eta_t_mid, A_bar, B_bar, B_tilde, I_M, beta, T, K)
        if feasible:
            best_eta_t = eta_t_mid
            best_powers = powers
            eta_t_lower = eta_t_mid
        else:
            eta_t_upper = eta_t_mid
    print('Bisection iteration:', itr_Bis)
    return best_eta_t, best_powers

# Example usage
max_eta_t, optimal_powers = bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, beta, T, K)
print("Maximum eta_t:", max_eta_t)
print(" Optimal power allocations:")
for t in range(T):
    print(f"Powers: {optimal_powers}")

# Compute SINR and latencies
SINR_optimal = compute_SINR(max_eta_t, optimal_powers, A_bar, B_bar, B_tilde, I_M, beta, K)
latencies_optimal = compute_latencies(SINR_optimal, beta, K)

# Print latencies
print("\nLatencies:")
#for t in range(T):
for j in range(K):
    print(f" User {j + 1}: {latencies_optimal[t, j]}")
# Out:
# Bisection iteration: 24
# Maximum eta_t: 0
#  Optimal power allocations:
# Powers: None
# C:\Users\afmb\AppData\Local\Temp\ipykernel_18000\713667213.py:24: RuntimeWarning: overflow encountered in power
#   gamma_t = 2 ** (eta_t * beta) - 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 90>()
#      87     print(f"Powers: {optimal_powers}")
#      89 # Compute SINR and latencies
# ---> 90 SINR_optimal = compute_SINR(max_eta_t, optimal_powers, A_bar, B_bar, B_tilde, I_M, beta, K)
#      91 latencies_optimal = compute_latencies(SINR_optimal, beta, K)
#      93 # Print latencies
#
# Input In [8], in compute_SINR(eta_t, powers, A_bar, B_bar, B_tilde, I_M, beta, K)
#      45     gamma_t = 2 ** (eta_t * beta/(2e6)) - 1
#      46     for j in range(K):
# ---> 47         interference = np.sum(powers * B_tilde[j]) + I_M[j]
#      48         SINR[ j] = A_bar[j] * powers[ j] / (B_bar[j] * powers[ j] + interference)
#      49 return SINR
#
# TypeError: unsupported operand type(s) for *: 'NoneType' and 'float'

# %%
num_global_iterations = 15
num_clients= 5
tau_p = min(K,10) #Orthogonal sequences if tau_p=K, else tau_p = 10

tau_c = 200
prelogFactor = (tau_c-tau_p)/(tau_c)
BW = 20e6
B_tau = BW*prelogFactor

# %%
# This is for Lambda1 = sqrt(Aj) and Lambda31 = log2(1 + A/(B + \sum B_tilde + I_M)) 

Bits1 = np.array([[  464797.,   468610.,   465851.,   469044.,   473446.,   484389.,
          498804.,   577234.,   518985.,   522891.,   528936.,   554077.,
          549365.,   539042.,   587185.],
       [  467618.,   478375.,   463619.,   525929.,   536655.,   535322.,
          521062.,   584085.,   644845.,   567841.,   619549.,   497812.,
          571344.,   614093.,   536314.],
       [10712467.,  2916339.,  3820237.,  4054411.,  4155843.,  4130547.,
         4286260.,  4405052.,  4573134.,  4663747.,  4798845.,  5013086.,
         5037204.,  5051960.,  5113774.],
       [  480359.,   519047.,   495766.,   703156.,   612264.,   645155.,
          674419.,   997346.,  1044900.,  1014458.,   964672.,   835123.,
          891481.,   925705.,  1076923.],
       [  473508.,   527138.,   625160.,   665429.,   848236.,   476143.,
          603646.,   817856.,   988325.,   996168.,   919164.,  1088858.,
          952520.,   732544.,   870556.]])

Bits31 = np.array([[ 463123.,  464177.,  462937.,  468672.,  477259.,  462627.,
         472702.,  488884.,  488574.,  488357.,  481475.,  500664.,
         489225.,  471803.,  489969.],
       [ 463774.,  462627.,  464022.,  464828.,  462906.,  469230.,
         471834.,  473198.,  467370.,  468145.,  464797.,  465045.,
         464828.,  465231.,  467091.],
       [9721645., 2493437., 2880162., 2775320., 2951493., 3373248.,
        3752378., 3783564., 3850276., 3945384., 3995852., 4015475.,
        4014948., 4026139., 4060642.],
       [ 517342.,  588766.,  547660.,  642086.,  856389.,  652316.,
         980947., 1217229., 1115735.,  997439., 1003143., 1117595.,
        1080829., 1061826., 1186570.],
       [ 817453., 1077822.,  949575., 1482186., 1780561., 1837043.,
        1895416., 2076084., 2001529., 2222776., 2362059., 2346466.,
        2387634., 2593040., 2650266.]])

# %%
for k in range(num_global_iterations):
    print('k:', k)
    max_eta_t, optimal_powers = bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, Bits1[:,k]/B_tau, T, K)
    print("Maximum eta_t:", max_eta_t)
   # print(" Optimal power allocations:")

    #print(f"Powers: {optimal_powers}")
    # Compute SINR and latencies
    SINR_optimal = compute_SINR(max_eta_t, optimal_powers, A_bar, B_bar, B_tilde, I_M, Bits1[:,k])
    latencies_optimal = compute_latencies(SINR_optimal, Bits1[:,k])
    print('Latency:',latencies_optimal/B_tau)
    print('max latency:', np.max(latencies_optimal/B_tau))
    print('---Lambda31----')
    max_eta_t3, optimal_powers3 = bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, Bits31[:,k]/B_tau, T, K)
    print("Maximum eta_t:", max_eta_t)
    #print(" Optimal power allocations:")
    
    #print(f"Powers: {optimal_powers}")
    # Compute SINR and latencies
    SINR_optimal = compute_SINR(max_eta_t3, optimal_powers3, A_bar, B_bar, B_tilde, I_M, Bits31[:,k])
    latencies_optimal3 = compute_latencies(SINR_optimal, Bits31[:,k])
    print('Latency:',latencies_optimal3/B_tau)
    print('max latency:', np.max(latencies_optimal3/B_tau))
    print('--- For FedAvg ------------')
    max_eta_t_f, optimal_powers_f = bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, beta/B_tau, T, K)
    print("Maximum eta_t_f:", max_eta_t_f)
   # print(" Optimal power allocations:")

    #print(f"Powers: {optimal_powers}")
    # Compute SINR and latencies
    SINR_optimal_f = compute_SINR(max_eta_t_f, optimal_powers_f, A_bar, B_bar, B_tilde, I_M, beta)
    latencies_optimal_f = compute_latencies(SINR_optimal_f, beta)
    print('Latency:',latencies_optimal_f/B_tau)
    print('max latency:', np.max(latencies_optimal_f/B_tau))
    print('-----------------------------------------------------------------------------')
# Out:
# k: 0
# Bisection iteration: 24
# Maximum eta_t: 4.540690779685974
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
#       4  print("Maximum eta_t:", max_eta_t)
#       5 # print(" Optimal power allocations:")
#       6
#       7  #print(f"Powers: {optimal_powers}")
#       8  # Compute SINR and latencies
# ----> 9  SINR_optimal = compute_SINR(max_eta_t, optimal_powers, A_bar, B_bar, B_tilde, I_M, Bits1[:,k])
#      10  latencies_optimal = compute_latencies(SINR_optimal, Bits1[:,k])
#      11  print('Latency:',latencies_optimal/B_tau)
#
# TypeError: compute_SINR() missing 1 required positional argument: 'K'

# %%
# This is for Lambda1 = log2(1 + SNR) not SINR and Lambda31 = lg2(1+SINR) as previous
Bits1 = np.array([[7710241., 2760347., 3429699., 3902542., 4054659., 4469873.,
        4755693., 4854366., 4829721., 4954124., 4985496., 5000500.,
        5123074., 5155655., 5362115.],
       [ 479057.,  498587.,  488667.,  555782.,  637250.,  915196.,
        1005158., 1012319.,  728700., 1120416.,  905214., 1136288.,
        2158730., 2331400., 2391571., 1862618., 2478557., 2631945.,
        2575494., 2766206., 2748691.]])

for k in range(num_global_iterations):
    print('k:', k)
    max_eta_t, optimal_powers = bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, Bits1[:,k]/B_tau, T, K)
    print("Maximum eta_t:", max_eta_t)
   # print(" Optimal power allocations:")

    #print(f"Powers: {optimal_powers}")
    # Compute SINR and latencies
    SINR_optimal = compute_SINR(max_eta_t, optimal_powers, A_bar, B_bar, B_tilde, I_M, Bits1[:,k])
    latencies_optimal = compute_latencies(SINR_optimal, Bits1[:,k])
    print('Latency:',latencies_optimal/B_tau)
    print('max latency:', np.max(latencies_optimal/B_tau))
    print('---Lambda31----')
    max_eta_t3, optimal_powers3 = bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, Bits31[:,k]/B_tau, T, K)
    print("Maximum eta_t:", max_eta_t)
    #print(" Optimal power allocations:")
    
    #print(f"Powers: {optimal_powers}")
    # Compute SINR and latencies
    SINR_optimal = compute_SINR(max_eta_t3, optimal_powers3, A_bar, B_bar, B_tilde, I_M, Bits31[:,k])
    latencies_optimal3 = compute_latencies(SINR_optimal, Bits31[:,k])
    print('Latency:',latencies_optimal3/B_tau)
    print('max latency:', np.max(latencies_optimal3/B_tau))
    print('--- For FedAvg ------------')
    max_eta_t_f, optimal_powers_f = bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, beta/B_tau, T, K)
    print("Maximum eta_t_f:", max_eta_t_f)
   # print(" Optimal power allocations:")

    #print(f"Powers: {optimal_powers}")
    # Compute SINR and latencies
    SINR_optimal_f = compute_SINR(max_eta_t_f, optimal_powers_f, A_bar, B_bar, B_tilde, I_M, beta)
    latencies_optimal_f = compute_latencies(SINR_optimal_f, beta)
    print('Latency:',latencies_optimal_f/B_tau)
    print('max latency:', np.max(latencies_optimal_f/B_tau))
    print('-----------------------------------------------------------------------------')
# Out:
# k: 0
# Bisection iteration: 24
# Maximum eta_t: 4.170967936515808
# Latency: [[0.06402734 0.01846411 1.10019786 0.47302226 0.2397525 ]]
# max latency: 1.1001978555149317
# ---Lambda31----
# Bisection iteration: 24
# Maximum eta_t: 4.170967936515808
# Latency: [[0.1850061  0.01643797 0.18705683 0.1751588  0.18757273]]
# max latency: 0.1875727314327802
# --- For FedAvg ------------
# Bisection iteration: 24
# Maximum eta_t_f: 3.149656057357788
# Latency: [[0.56623317 0.58309816 0.31420449 0.31745443 0.31749498]]
# max latency: 0.5830981604678843
# -----------------------------------------------------------------------------
# k: 1
# Bisection iteration: 24
# Maximum eta_t: 9.999999403953552
# Latency: [[0.00801582 0.00918164 0.0101278  0.09010605 0.10000001]]
# max latency: 0.10000000596046481
# ---Lambda31----
# Bisection iteration: 24
# Maximum eta_t: 9.999999403953552
# Latency: [[0.00803521 0.00765288 0.05810003 0.08845272 0.10000001]]
# max latency: 0.10000000596046481
# --- For FedAvg ------------
# Bisection iteration: 24
# Maximum eta_t_f: 3.149656057357788
# Latency: [[0.56623317 0.58309816 0.31420449 0.31745443 0.31749498]]
# max latency: 0.5830981604678843
# -----------------------------------------------------------------------------
# k: 2
# Bisection iteration: 24
# Maximum eta_t: 9.999999403953552
# Latency: [[0.00947348 0.0140599  0.01045114 0.09384068 0.10000001]]
# max latency: 0.10000000596046484
# ---Lambda31----
# Bisection iteration: 24
# Maximum eta_t: 9.999999403953552
# Latency: [[0.00805274 0.00774205 0.05584717 0.08924386 0.10000001]]
# max latency: 0.10000000596046488
# --- For FedAvg ------------
# Bisection iteration: 24
# Maximum eta_t_f: 3.149656057357788
# Latency: [[0.56623317 0.58309816 0.31420449 0.31745443 0.31749498]]
# max latency: 0.5830981604678843
# -----------------------------------------------------------------------------
# k: 3
# Bisection iteration: 24
# Maximum eta_t: 9.999999403953552
# Latency: [[0.01148445 0.02105421 0.01048481 0.0961331  0.10000001]]
# max latency: 0.10000000596046482
# ---Lambda31----
# Bisection iteration: 24
# Maximum eta_t: 9.999999403953552
# Latency: [[0.00836853 0.00780839 0.05987967 0.08918831 0.10000001]]
# max latency: 0.10000000596046482
# --- For FedAvg ------------
# Bisection iteration: 24
# Maximum eta_t_f: 3.149656057357788
# Latency: [[0.56623317 0.58309816 0.31420449 0.31745443 0.31749498]]
# max latency: 0.5830981604678843
# -----------------------------------------------------------------------------
# k: 4
# Bisection iteration: 24
# Maximum eta_t: 9.999999403953552
# Latency: [[0.01230496 0.02255224 0.01071541 0.09659744 0.10000001]]
# max latency: 0.10000000596046485
# ---Lambda31----
# Bisection iteration: 24
# Maximum eta_t: 9.999999403953552
# Latency: [[0.00834004 0.00782381 0.0596583  0.08967556 0.10000001]]
# max latency: 0.10000000596046484
# --- For FedAvg ------------
# Bisection iteration: 24
# Maximum eta_t_f: 3.149656057357788
# Latency: [[0.56623317 0.58309816 0.31420449 0.31745443 0.31749498]]
# max latency: 0.5830981604678843
# -----------------------------------------------------------------------------
# k: 5
# Bisection iteration: 24
# Maximum eta_t: 9.999999403953552
# Latency: [[0.01083547 0.01864642 0.01103594 0.0957037  0.10000001]]
# max latency: 0.10000000596046482
# ---Lambda31----
# Bisection iteration: 24
# Maximum eta_t: 9.999999403953552
# Latency: [[0.00838261 0.00792699 0.06375737 0.09011866 0.10000001]]
# max latency: 0.10000000596046482
# --- For FedAvg ------------
# Bisection iteration: 24
# Maximum eta_t_f: 3.149656057357788
# Latency: [[0.56623317 0.58309816 0.31420449 0.31745443 0.31749498]]
# max latency: 0.5830981604678843
# -----------------------------------------------------------------------------
# k: 6
# Bisection iteration: 24
# Maximum eta_t: 9.999999403953552
# Latency: [[0.00981345 0.01484812 0.01299029 0.09464963 0.10000001]]
# max latency: 0.10000000596046484
# ---Lambda31----
# Bisection iteration: 24
# Maximum eta_t: 9.999999403953552
# Latency: [[0.00859054 0.00800233 0.0670392  0.09034321 0.10000001]]
# max latency: 0.10000000596046484
# --- For FedAvg ------------
# Bisection iteration: 24
# Maximum eta_t_f: 3.149656057357788
# Latency: [[0.56623317 0.58309816 0.31420449 0.31745443 0.31749498]]
# max latency: 0.5830981604678843
# -----------------------------------------------------------------------------
# k: 7
# Bisection iteration: 24
# Maximum eta_t: 9.701204895973206
# Latency: [[0.03544362 0.02712848 0.44341225 0.11637129 0.10307998]]
# max latency: 0.4434122526679238
# ---Lambda31----
# Bisection iteration: 24
# Maximum eta_t: 9.701204895973206
# Latency: [[0.00908009 0.00807761 0.07434669 0.09068286 0.10000001]]
# max latency: 0.10000000596046481
# --- For FedAvg ------------
# Bisection iteration: 24
# Maximum eta_t_f: 3.149656057357788
# Latency: [[0.56623317 0.58309816 0.31420449 0.31745443 0.31749498]]
# max latency: 0.5830981604678843
# -----------------------------------------------------------------------------
# k: 8
# Bisection iteration: 24
# Maximum eta_t: 9.422082901000977
# Latency: [[0.03663601 0.02820492 0.45478783 0.11995408 0.10613364]]
# max latency: 0.45478782996172823
# ---Lambda31----
# Bisection iteration: 24
# Maximum eta_t: 9.422082901000977
# Latency: [[0.00914934 0.00801101 0.0756117  0.09049006 0.10000001]]
# max latency: 0.10000000596046485
# --- For FedAvg ------------
# Bisection iteration: 24
# Maximum eta_t_f: 3.149656057357788
# Latency: [[0.56623317 0.58309816 0.31420449 0.31745443 0.31749498]]
# max latency: 0.5830981604678843
# -----------------------------------------------------------------------------
# k: 9
# Bisection iteration: 24
# Maximum eta_t: 9.055750966072083
# Latency: [[0.03650524 0.02534414 0.47812289 0.12853205 0.11042706]]
# max latency: 0.4781228892673252
# ---Lambda31----
# Bisection iteration: 24
# Maximum eta_t: 9.055750966072083
# Latency: [[0.00908073 0.00811069 0.07645763 0.09062067 0.10000001]]
# max latency: 0.10000000596046484
# --- For FedAvg ------------
# Bisection iteration: 24
# Maximum eta_t_f: 3.149656057357788
# Latency: [[0.56623317 0.58309816 0.31420449 0.31745443 0.31749498]]
# max latency: 0.5830981604678843
# -----------------------------------------------------------------------------
# k: 10
# Bisection iteration: 24
# Maximum eta_t: 8.977548480033875
# Latency: [[0.03831548 0.0305741  0.48053332 0.12458423 0.11138898]]
# max latency: 0.4805333174803295
# ---Lambda31----
# Bisection iteration: 24
# Maximum eta_t: 8.977548480033875
# Latency: [[0.00908704 0.00806485 0.07810247 0.09060937 0.10000001]]
# max latency: 0.10000000596046481
# --- For FedAvg ------------
# Bisection iteration: 24
# Maximum eta_t_f: 3.149656057357788
# Latency: [[0.56623317 0.58309816 0.31420449 0.31745443 0.31749498]]
# max latency: 0.5830981604678843
# -----------------------------------------------------------------------------
# k: 11
# Bisection iteration: 24
# Maximum eta_t: 8.798880577087402
# Latency: [[0.03759521 0.02658416 0.49363085 0.13314847 0.11365082]]
# max latency: 0.4936308548800082
# ---Lambda31----
# Bisection iteration: 24
# Maximum eta_t: 8.798880577087402
# Latency: [[0.00939338 0.00796669 0.07768517 0.09012863 0.10000001]]
# max latency: 0.10000000596046482
# --- For FedAvg ------------
# Bisection iteration: 24
# Maximum eta_t_f: 3.149656057357788
# Latency: [[0.56623317 0.58309816 0.31420449 0.31745443 0.31749498]]
# max latency: 0.5830981604678843
# -----------------------------------------------------------------------------
# k: 12
# Bisection iteration:
# C:\Users\afmb\AppData\Local\Temp\ipykernel_12124\1438472338.py:45: RuntimeWarning: overflow encountered in power
#   gamma_t = 2 ** (eta_t * beta) - 1
#  24
# Maximum eta_t: 8.799472451210022
# Latency: [[0.03919149 0.0321081  0.49591891 0.12726692 0.11364318]]
# max latency: 0.4959189101198891
# ---Lambda31----
# Bisection iteration: 24
# Maximum eta_t: 8.799472451210022
# Latency: [[0.0094527  0.00795987 0.07924135 0.09031937 0.10000001]]
# max latency: 0.10000000596046485
# --- For FedAvg ------------
# Bisection iteration: 24
# Maximum eta_t_f: 3.149656057357788
# Latency: [[0.56623317 0.58309816 0.31420449 0.31745443 0.31749498]]
# max latency: 0.5830981604678843
# -----------------------------------------------------------------------------
# k: 13
# Bisection iteration: 24
# Maximum eta_t: 8.707118034362793
# Latency: [[0.03966625 0.0322229  0.4975119  0.12819933 0.11484856]]
# max latency: 0.49751190111351884
# ---Lambda31----
# Bisection iteration: 24
# Maximum eta_t: 8.707118034362793
# Latency: [[0.00927835 0.00812218 0.07898353 0.09093888 0.10000001]]
# max latency: 0.10000000596046482
# --- For FedAvg ------------
# Bisection iteration: 24
# Maximum eta_t_f: 3.149656057357788
# Latency: [[0.56623317 0.58309816 0.31420449 0.31745443 0.31749498]]
# max latency: 0.5830981604678843
# -----------------------------------------------------------------------------
# k: 14
# Bisection iteration: 24
# Maximum eta_t: 8.717289566993713
# Latency: [[0.03999456 0.03365718 0.49284134 0.12723449 0.11471456]]
# max latency: 0.49284133687738424
# ---Lambda31----
# Bisection iteration: 24
# Maximum eta_t: 8.717289566993713
# Latency: [[0.00940771 0.00830223 0.07958521 0.09104231 0.10000001]]
# max latency: 0.10000000596046484
# --- For FedAvg ------------
# Bisection iteration: 24
# Maximum eta_t_f: 3.149656057357788
# Latency: [[0.56623317 0.58309816 0.31420449 0.31745443 0.31749498]]
# max latency: 0.5830981604678843
# -----------------------------------------------------------------------------

# %% [markdown]
# #The fillowing code is the the SLSQP that solves the optimization problem

# %%
import numpy as np
import math
from scipy.optimize import minimize

# Define parameters
T = 1  # single time slot for simplicity
K = 5  # number of users
B_tilde = np.array([[0.0, 0.00280774, 0.00227045, 0.00599378, 0.00054239],
                    [0.00280774, 0.0, 0.00090963, 0.10872945, 0.00079498],
                    [0.00227045, 0.00090963, 0.0, 0.00180449, 0.03946987],
                    [0.00599378, 0.10872945, 0.00180449, 0.0, 0.00094696],
                    [0.00054239, 0.00079498, 0.03946987, 0.00094696, 0.0]])
A_bar = 2 * np.array([0.038254, 0.37979634, 6.42646204, 1.4801049, 1.43769989])
B_bar = np.array([0.00206423, 0.04449928, 1.3862424, 0.29103015, 0.29611187])
I_M = np.array([7.78643045e-13, 2.45343970e-12, 1.00922029e-11, 4.84335440e-12, 4.77346915e-12])
beta = np.array([8, 6, 8, 2, 7])

# Function to check feasibility of power allocations and return power values
def check_feasibility(eta_t, A_bar, B_bar, B_tilde, I_M, beta, T, K):
    powers = (1/K)*np.ones((T, K))
    gamma_t = 2 ** (eta_t * beta) - 1
    for t in range(T):
        # Iteratively solve for power allocations
        for iteration in range(100):  # Arbitrary number of iterations for convergence
            powers_prev = np.copy(powers[t])
            for j in range(K):
                numerator = gamma_t[j] * (np.sum(powers[t] * B_tilde[j]) + I_M[j] - powers[t, j] * B_tilde[j, j])
                denominator = A_bar[j] - gamma_t[j] * B_bar[j]
                if denominator <= 0:
                    return False, None
                powers[t, j] = numerator / denominator
            # Check for convergence
            if np.allclose(powers_prev, powers[t], atol=1e-6):
                break
        # Check feasibility of the computed powers
        if np.any(powers[t] < 0) or np.any(powers[t] > 1):
            return False, None
    return True, powers

# Function to compute SINR_t^j given powers
def compute_SINR(eta_t, powers, A_bar, B_bar, B_tilde, I_M, beta):
    T, K = powers.shape
    SINR = np.zeros((T, K))
    for t in range(T):
        for j in range(K):
            interference = np.sum(powers[t] * B_tilde[j]) + I_M[j] - powers[t, j] * B_tilde[j, j]
            SINR[t, j] = A_bar[j] * powers[t, j] / (B_bar[j] * powers[t, j] + interference)
    return SINR

# Function to compute latencies ell_t^j given SINR_t^j
def compute_latencies(SINR, beta):
    T, K = SINR.shape
    latencies = np.zeros((T, K))
    for t in range(T):
        for j in range(K):
            if SINR[t, j] > 0:
                latencies[t, j] = beta[j] / math.log2(1 + SINR[t, j])
            else:
                latencies[t, j] = float('inf')  # Handle cases where SINR[t, j] is zero
    return latencies

# Bisection method to find maximum eta_t and store power allocations
def bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, beta, T, K, eta_t_lower=0.0, eta_t_upper=10.0, tolerance=1e-6):
    best_eta_t = eta_t_lower
    best_powers = None
    while eta_t_upper - eta_t_lower > tolerance:
        eta_t_mid = (eta_t_lower + eta_t_upper) / 2.0
        feasible, powers = check_feasibility(eta_t_mid, A_bar, B_bar, B_tilde, I_M, beta, T, K)
        if feasible:
            best_eta_t = eta_t_mid
            best_powers = powers
            eta_t_lower = eta_t_mid
        else:
            eta_t_upper = eta_t_mid
    return best_eta_t, best_powers

# Example usage
max_eta_t, optimal_powers = bisection_maximize_eta_t(A_bar, B_bar, B_tilde, I_M, beta, T, K)
print("Maximum eta_t:", max_eta_t)
print("Original Optimal power allocations:")
for t in range(T):
    print(f"Powers: {optimal_powers[t]}")

# Compute SINR and latencies
SINR_optimal = compute_SINR(max_eta_t, optimal_powers, A_bar, B_bar, B_tilde, I_M, beta)
latencies_optimal = compute_latencies(SINR_optimal, beta)

# Print latencies
print("\nLatencies:")
for t in range(T):
    for j in range(K):
        print(f" User {j + 1}: {latencies_optimal[t, j]}")
# Out:
# Maximum eta_t: 0.4186445474624634
# Original Optimal power allocations:
# Powers: [0.39680664 0.02099984 0.99720833 0.00193908 0.2869322 ]
#
# Latencies:
#  User 1: 2.3903869252103953
#  User 2: 2.38976912165146
#  User 3: 2.3886798307841506
#  User 4: 2.388827744114702
#  User 5: 2.3886612307775543
